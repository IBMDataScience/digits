# %% [markdown]
# # Install Sklearn Package

# %%
# !pip install sklearn

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")
# %pylab inline
import matplotlib.pyplot as plt

from sklearn.externals import joblib
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, train_test_split
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load data

# %%
digits = load_digits()
X = digits.images
X = X.reshape(len(X),-1)
y = digits.target

# %% [markdown]
# # Visualize images of handwritten digits

# %%
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20,30))
for i in range(10):
    axes[i].imshow(X[i].reshape(8,8), cmap='gray')

# %% [markdown]
# # An image is a matrix of pixels
#
# + show an image of a zero

# %%
_= imshow(X[0].reshape(8,8), cmap='gray')

# %% [markdown]
# + show the matrix of pixel representation of the same image

# %%
X[0].reshape(8,8)
# Out:
# array([[  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.],
#        [  0.,   0.,  13.,  15.,  10.,  15.,   5.,   0.],
#        [  0.,   3.,  15.,   2.,   0.,  11.,   8.,   0.],
#        [  0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.],
#        [  0.,   5.,   8.,   0.,   0.,   9.,   8.,   0.],
#        [  0.,   4.,  11.,   0.,   1.,  12.,   7.,   0.],
#        [  0.,   2.,  14.,   5.,  10.,  12.,   0.,   0.],
#        [  0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.]])

# %% [markdown]
# + show the label (ground truth) of the image

# %%
print("Label is ",y[0])
# Out:
# Label is  0

# %% [markdown]
# # Split data into train and test sets

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y)

# %% [markdown]
# # Training a Classifier

# %%
classifier = SVC(gamma=0.001)
classifier.fit(X_train,y_train)
y_predicted = classifier.predict(X_test)
accuracy = round(accuracy_score(y_test, y_predicted)*100,2)
print("Prediction Accuracy :",accuracy,"%")
# Out:
# Prediction Accuracy : 98.89 %

# %% [markdown]
# #  5 fold Cross Validation

# %%
crossval_accuracies = cross_val_score(classifier, X,y,scoring='accuracy',cv=5)
mean_accuracy = round(mean(crossval_accuracies)*100,2)
print("Mean Accuracy :", mean_accuracy,"%")
# Out:
# Mean Accuracy : 97.16 %

# %% [markdown]
# # Use Trained Model to Predict

# %%
image = X_test[1].reshape(1,-1)

_=plt.imshow(image.reshape(8,8), cmap='gray')

# %%
predicted_digit = classifier.predict(image)[0]
print("The predicted value for the above image is : ",predicted_digit)
# Out:
# The predicted value for the above image is :  0
